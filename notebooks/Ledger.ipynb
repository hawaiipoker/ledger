# %%
import argparse
import json
from heapq import heapify, heappush, heappop
from googleapiclient.discovery import build
import pandas as pd

def compute_transactions(ledger):
    assert round(sum(ledger.values()), 2) == 0
    neg = []
    pos = []
    for name, value in ledger.items():
        if value < 0:
            heappush(neg, (value, value, name))
        else:
            heappush(pos, (-value, value, name))
    transactions = []
    while neg and pos:
        _, debt, debtee = heappop(pos)
        _, payment, debtor = heappop(neg)
        unaccounted = round(debt + payment, 2)
        if unaccounted > 0:
            heappush(pos, (-unaccounted, unaccounted, debtee))
        elif unaccounted < 0:
            heappush(neg, (unaccounted, unaccounted, debtor))
        amount = min(debt, -payment)
        transactions.append((debtee, debtor, amount))
    assert len(neg) == 0
    assert len(pos) == 0
    transactions = sorted(transactions)
    return transactions

# %%
API_KEY = "AIzaSyBV5mclhpS8zjLDkuniZDbh5LWx-GufQWo"
SPREADSHEET_ID = "1-S9kxCk_HeXw4I7onMNAZia0mhJ-z_8MtNCwVX3F0GY"

service = build('sheets', 'v4', developerKey=API_KEY)
sheet_api = service.spreadsheets()
metadata = (
    sheet_api.get(spreadsheetId=SPREADSHEET_ID)
    .execute()
)

# %%
form_responses = metadata["sheets"][0]
name = form_responses["properties"]["title"]
data = (
    sheet_api.values()
    .get(spreadsheetId=SPREADSHEET_ID, range=name)
    .execute()["values"]
)
venmo_table = pd.DataFrame([row[1:4] for row in data[1:]], columns=data[0][1:4]).dropna()
venmo_table.columns = ["Name", "Venmo", "Alias"]
for col in venmo_table:
    venmo_table[col] = venmo_table[col].str.strip()
venmo_table["Key"] = venmo_table.Name.str.replace(" ", "").str.lower()
has_at = ~venmo_table.Venmo.str.startswith("@")
venmo_table.loc[has_at, "Venmo"] = "@" + venmo_table.loc[has_at, "Venmo"]
real_names = venmo_table.dropna()[["Name", "Venmo", "Key"]]
real_names["RealName"] = real_names["Name"]
real_names["IsAlias"] = False
aliases = venmo_table.dropna()[["Name", "Alias", "Venmo"]]
aliases = aliases.rename(columns={"Alias": "Name", "Name": "RealName"})
aliases["Key"] = aliases.Name.str.replace(" ", "").str.lower()
aliases["IsAlias"] = True
venmo = pd.concat([real_names, aliases]).reset_index(drop=True)
venmo = venmo.drop_duplicates(["Key", "Venmo"])[["Key", "Venmo", "RealName", "IsAlias"]]
venmo.RealName = venmo.RealName.str.title()
venmo
# Out:
#                   Key           Venmo           RealName  IsAlias
# 0            garychao    @gary-chao-1          Gary Chao    False
# 1    vishnusundaresan       @Uber-Bus  Vishnu Sundaresan    False
# 2            dannykim  @dannyinmookim          Danny Kim    False
# 3           denniswei      @DennisWei         Dennis Wei    False
# 4              benlow       @benlowkh            Ben Low    False
# ..                ...             ...                ...      ...
# 168                         @Bill-Lou           Bill Lou     True
# 169                     @jonathanzhou      Jonathan Zhou     True
# 170                     @Ernie-Chen-1         Ernie Chen     True
# 171                      @seungwooson       Seungwoo Son     True
# 172                     @Alexanderpae           Alex Pae     True
#
# [168 rows x 4 columns]

# %%
ledger_sheet_name = metadata["sheets"][1]["properties"]["title"]
data = (
    sheet_api.values()
    .get(spreadsheetId=SPREADSHEET_ID, range=ledger_sheet_name)
    .execute()["values"]
)
ledger_df = pd.DataFrame([row for row in data[2:]], columns=data[0])
ledger_df.Name = ledger_df.Name.str.strip()
ledger_df["Key"] = ledger_df.Name.str.replace(" ", "").str.lower()
ledger_df.PnL = ledger_df.PnL.astype(float).round(2)
ledger_df
# Out:
#           Date            Name      PnL            Key
# 0   2020-09-16        Bill Cao -1039.00        billcao
# 1   2020-09-16      ThiccyThot  -164.00     thiccythot
# 2   2020-09-16       Chris Chu  -413.00       chrischu
# 3   2020-09-16   Jonathan Zhou  -400.00   jonathanzhou
# 4   2020-09-16         eric he  -383.00         eriche
# 5   2020-09-16    Seungwoo Son  -659.00    seungwooson
# 6   2020-09-16      Eric Hsiao   806.99      erichsiao
# 7   2020-09-16          Eshaan  2546.00         eshaan
# 8   2020-09-16      Jarry Xiao -2000.00      jarryxiao
# 9   2020-09-16           Vdong   428.00          vdong
# 10  2020-09-16   Jonathan Wang   218.00   jonathanwang
# 11  2020-09-16  Andrei Curelea   101.00  andreicurelea
# 12  2020-09-16   Victor Garcia  2512.22   victorgarcia
# 13  2020-09-16      Eric Hsiao     0.00      erichsiao
# 14  2020-09-16         eric he -2592.00         eriche
# 15  2020-09-16        Alex Pae  -427.00        alexpae
# 16  2020-09-16          will z  1294.89          willz
# 17  2020-09-16     Jessica Shu  1759.00     jessicashu
# 18  2020-09-16      yiwen song    21.16      yiwensong
# 19  2020-09-16       Gary Chao  2435.85       garychao
# 20  2020-09-16       Kunal Roy  -979.00       kunalroy
# 21  2020-09-16   Dixee Kimball  -395.00   dixeekimball
# 22  2020-09-16           Ray S -1887.00           rays
# 23  2020-09-16     Kevin Huang   -31.00     kevinhuang
# 24  2020-09-16           Amrit -1576.00          amrit
# 25  2020-09-16      Dennis Wei   -25.62      denniswei
# 26  2020-09-16   Roy Nakamaejo -3111.60   roynakamaejo
# 27  2020-09-16      gary chao2 -1062.00      garychao2
# 28  2020-09-16      Kevin Feng  1342.00      kevinfeng
# 29  2020-09-16    Jordan Meyer -1373.00    jordanmeyer
# 30  2020-09-16      yiwen song     9.37      yiwensong
# 31  2020-09-16        Bill Lou  1970.74        billlou
# 32  2020-09-16   Jonathan Wang  3092.00   jonathanwang
# 33  2020-09-16         Ben Low   -20.00         benlow

# %%
merged = ledger_df[["Date", "Key", "PnL"]].merge(venmo, on="Key", how="left")
result = merged.groupby(["Date", "RealName", "Venmo"])[["PnL"]].sum().reset_index()
result
# Out:
#           Date         RealName             Venmo      PnL
# 0   2020-09-16         Alex Dai         @Alex-dai  -164.00
# 1   2020-09-16         Alex Pae     @Alexanderpae  -427.00
# 2   2020-09-16     Amrit Ayalur            @amrit -1576.00
# 3   2020-09-16   Andrei Curelea   @Andrei-Curelea   101.00
# 4   2020-09-16          Ben Low         @benlowkh   -20.00
# 5   2020-09-16         Bill Cao         @Bill-Cao -1039.00
# 6   2020-09-16         Bill Lou         @Bill-Lou  1970.74
# 7   2020-09-16  Christopher Chu      @Chris-Chu-8  -413.00
# 8   2020-09-16       Dennis Wei        @DennisWei   -25.62
# 9   2020-09-16    Dixee Kimball    @Dixee-Kimball  -395.00
# 10  2020-09-16          Eric He          @eric_he -2975.00
# 11  2020-09-16       Eric Hsiao      @Erichsiao43   806.99
# 12  2020-09-16    Eshaan Bhalla          @eshaanb  2546.00
# 13  2020-09-16        Gary Chao      @gary-chao-1  1373.85
# 14  2020-09-16       Jarry Xiao       @Jarry-Xiao -2000.00
# 15  2020-09-16      Jessica Shu       @Jessicashu  1759.00
# 16  2020-09-16    Jonathan Wang          @jjxwang  3310.00
# 17  2020-09-16    Jonathan Zhou     @jonathanzhou  -400.00
# 18  2020-09-16     Jordan Meyer  @Jordan-Meyer-19 -1373.00
# 19  2020-09-16       Kevin Feng     @Kevin-feng-5  1342.00
# 20  2020-09-16      Kevin Huang      @Kevin_Huang   -31.00
# 21  2020-09-16        Kunal Roy      @Kunal-Roy-1  -979.00
# 22  2020-09-16     Raymond Shin      @raymondshin -1887.00
# 23  2020-09-16    Roy Nakamaejo    @Roy-Nakamaejo -3111.60
# 24  2020-09-16     Seungwoo Son      @seungwooson  -659.00
# 25  2020-09-16      Victor Dong      @victor-dong   428.00
# 26  2020-09-16    Victor Garcia       @vmgarcia12  2512.22
# 27  2020-09-16       Will Zhang     @will-zhang-2  1294.89
# 28  2020-09-16       Yiwen Song       @yiwen-song    30.53

# %%
date = '2020-09-16'
ledger = dict(result.query("Date == @date")[["RealName", "PnL"]].values)
txns = compute_transactions(ledger)
payments = pd.DataFrame(txns, columns=["To", "From", "Amount"])
payments = payments.merge(venmo[~venmo.IsAlias], left_on="From", right_on="RealName")
payments = payments.merge(venmo[~venmo.IsAlias], left_on="To", right_on="RealName", suffixes=["", "To"])
payments = payments.sort_values("To")
payments
# Out:
#                 To             From   Amount             Key  \
# 0   Andrei Curelea  Christopher Chu    97.11  christopherchu
# 1   Andrei Curelea    Dixee Kimball     3.01    dixeekimball
# 2   Andrei Curelea    Jonathan Zhou     0.88    jonathanzhou
# 16        Bill Lou     Raymond Shin  1887.00     raymondshin
# 15        Bill Lou    Jonathan Zhou    83.74    jonathanzhou
# 25      Eric Hsiao         Alex Dai   147.99         alexdai
# 26      Eric Hsiao     Seungwoo Son   659.00     seungwooson
# 27   Eshaan Bhalla          Eric He  2546.00          eriche
# 17       Gary Chao    Jonathan Zhou     0.85    jonathanzhou
# 18       Gary Chao     Jordan Meyer  1373.00     jordanmeyer
# 5      Jessica Shu    Dixee Kimball   183.00    dixeekimball
# 6      Jessica Shu     Amrit Ayalur  1576.00     amritayalur
# 7    Jonathan Wang    Dixee Kimball   198.40    dixeekimball
# 8    Jonathan Wang    Roy Nakamaejo  3111.60    roynakamaejo
# 19      Kevin Feng    Jonathan Zhou   303.00    jonathanzhou
# 20      Kevin Feng         Bill Cao  1039.00         billcao
# 21     Victor Dong    Jonathan Zhou     1.00    jonathanzhou
# 22     Victor Dong         Alex Pae   427.00         alexpae
# 14   Victor Garcia      Kevin Huang    31.00      kevinhuang
# 11   Victor Garcia          Eric He   429.00          eriche
# 10   Victor Garcia         Alex Dai    16.01         alexdai
# 9    Victor Garcia    Dixee Kimball    10.59    dixeekimball
# 12   Victor Garcia       Dennis Wei    25.62       denniswei
# 13   Victor Garcia       Jarry Xiao  2000.00       jarryxiao
# 4       Will Zhang        Kunal Roy   979.00        kunalroy
# 3       Will Zhang  Christopher Chu   315.89  christopherchu
# 23      Yiwen Song    Jonathan Zhou    10.53    jonathanzhou
# 24      Yiwen Song          Ben Low    20.00          benlow
#
#                Venmo         RealName  IsAlias          KeyTo  \
# 0       @Chris-Chu-8  Christopher Chu    False  andreicurelea
# 1     @Dixee-Kimball    Dixee Kimball    False  andreicurelea
# 2      @jonathanzhou    Jonathan Zhou    False  andreicurelea
# 16      @raymondshin     Raymond Shin    False        billlou
# 15     @jonathanzhou    Jonathan Zhou    False        billlou
# 25         @Alex-dai         Alex Dai    False      erichsiao
# 26      @seungwooson     Seungwoo Son    False      erichsiao
# 27          @eric_he          Eric He    False   eshaanbhalla
# 17     @jonathanzhou    Jonathan Zhou    False       garychao
# 18  @Jordan-Meyer-19     Jordan Meyer    False       garychao
# 5     @Dixee-Kimball    Dixee Kimball    False     jessicashu
# 6             @amrit     Amrit Ayalur    False     jessicashu
# 7     @Dixee-Kimball    Dixee Kimball    False   jonathanwang
# 8     @Roy-Nakamaejo    Roy Nakamaejo    False   jonathanwang
# 19     @jonathanzhou    Jonathan Zhou    False      kevinfeng
# 20         @Bill-Cao         Bill Cao    False      kevinfeng
# 21     @jonathanzhou    Jonathan Zhou    False     victordong
# 22     @Alexanderpae         Alex Pae    False     victordong
# 14      @Kevin_Huang      Kevin Huang    False   victorgarcia
# 11          @eric_he          Eric He    False   victorgarcia
# 10         @Alex-dai         Alex Dai    False   victorgarcia
# 9     @Dixee-Kimball    Dixee Kimball    False   victorgarcia
# 12        @DennisWei       Dennis Wei    False   victorgarcia
# 13       @Jarry-Xiao       Jarry Xiao    False   victorgarcia
# 4       @Kunal-Roy-1        Kunal Roy    False      willzhang
# 3       @Chris-Chu-8  Christopher Chu    False      willzhang
# 23     @jonathanzhou    Jonathan Zhou    False      yiwensong
# 24         @benlowkh          Ben Low    False      yiwensong
#
#             VenmoTo      RealNameTo  IsAliasTo
# 0   @Andrei-Curelea  Andrei Curelea      False
# 1   @Andrei-Curelea  Andrei Curelea      False
# 2   @Andrei-Curelea  Andrei Curelea      False
# 16        @Bill-Lou        Bill Lou      False
# 15        @Bill-Lou        Bill Lou      False
# 25     @Erichsiao43      Eric Hsiao      False
# 26     @Erichsiao43      Eric Hsiao      False
# 27         @eshaanb   Eshaan Bhalla      False
# 17     @gary-chao-1       Gary Chao      False
# 18     @gary-chao-1       Gary Chao      False
# 5       @Jessicashu     Jessica Shu      False
# 6       @Jessicashu     Jessica Shu      False
# 7          @jjxwang   Jonathan Wang      False
# 8          @jjxwang   Jonathan Wang      False
# 19    @Kevin-feng-5      Kevin Feng      False
# 20    @Kevin-feng-5      Kevin Feng      False
# 21     @victor-dong     Victor Dong      False
# 22     @victor-dong     Victor Dong      False
# 14      @vmgarcia12   Victor Garcia      False
# 11      @vmgarcia12   Victor Garcia      False
# 10      @vmgarcia12   Victor Garcia      False
# 9       @vmgarcia12   Victor Garcia      False
# 12      @vmgarcia12   Victor Garcia      False
# 13      @vmgarcia12   Victor Garcia      False
# 4     @will-zhang-2      Will Zhang      False
# 3     @will-zhang-2      Will Zhang      False
# 23      @yiwen-song      Yiwen Song      False
# 24      @yiwen-song      Yiwen Song      False

# %%
totals = result.query("Date == @date")[["RealName", "PnL", "Venmo"]].sort_values("RealName")
print("Bills")
print()
print("======")
print()
for _, bill in totals.iterrows():
    sign = bill.PnL > 0
    amount = "${:.2f}".format(abs(bill.PnL))
    if not sign:
        amount = "-" + amount
    print(f"{bill.RealName} ({bill.Venmo}): {amount}")
print()
print("Transactions To Settle")
print()
print("======================")
print()
for _, tx in payments.iterrows():
    amount = "${:.2f}".format(abs(tx.Amount))
    print(f"{tx.To} ({tx.VenmoTo}) requests {amount} from {tx.From} ({tx.Venmo})")
# Out:
# Bills
#
# ======
#
# Alex Dai (@Alex-dai): -$164.00
# Alex Pae (@Alexanderpae): -$427.00
# Amrit Ayalur (@amrit): -$1576.00
# Andrei Curelea (@Andrei-Curelea): $101.00
# Ben Low (@benlowkh): -$20.00
# Bill Cao (@Bill-Cao): -$1039.00
# Bill Lou (@Bill-Lou): $1970.74
# Christopher Chu (@Chris-Chu-8): -$413.00
# Dennis Wei (@DennisWei): -$25.62
# Dixee Kimball (@Dixee-Kimball): -$395.00
# Eric He (@eric_he): -$2975.00
# Eric Hsiao (@Erichsiao43): $806.99
# Eshaan Bhalla (@eshaanb): $2546.00
# Gary Chao (@gary-chao-1): $1373.85
# Jarry Xiao (@Jarry-Xiao): -$2000.00
# Jessica Shu (@Jessicashu): $1759.00
# Jonathan Wang (@jjxwang): $3310.00
# Jonathan Zhou (@jonathanzhou): -$400.00
# Jordan Meyer (@Jordan-Meyer-19): -$1373.00
# Kevin Feng (@Kevin-feng-5): $1342.00
# Kevin Huang (@Kevin_Huang): -$31.00
# Kunal Roy (@Kunal-Roy-1): -$979.00
# Raymond Shin (@raymondshin): -$1887.00
# Roy Nakamaejo (@Roy-Nakamaejo): -$3111.60
# Seungwoo Son (@seungwooson): -$659.00
# Victor Dong (@victor-dong): $428.00
# Victor Garcia (@vmgarcia12): $2512.22
# Will Zhang (@will-zhang-2): $1294.89
# Yiwen Song (@yiwen-song): $30.53
#
# Transactions To Settle
#
# ======================
#
# Andrei Curelea (@Andrei-Curelea) requests $97.11 from Christopher Chu (@Chris-Chu-8)
# Andrei Curelea (@Andrei-Curelea) requests $3.01 from Dixee Kimball (@Dixee-Kimball)
# Andrei Curelea (@Andrei-Curelea) requests $0.88 from Jonathan Zhou (@jonathanzhou)
# Bill Lou (@Bill-Lou) requests $1887.00 from Raymond Shin (@raymondshin)
# Bill Lou (@Bill-Lou) requests $83.74 from Jonathan Zhou (@jonathanzhou)
# Eric Hsiao (@Erichsiao43) requests $147.99 from Alex Dai (@Alex-dai)
# Eric Hsiao (@Erichsiao43) requests $659.00 from Seungwoo Son (@seungwooson)
# Eshaan Bhalla (@eshaanb) requests $2546.00 from Eric He (@eric_he)
# Gary Chao (@gary-chao-1) requests $0.85 from Jonathan Zhou (@jonathanzhou)
# Gary Chao (@gary-chao-1) requests $1373.00 from Jordan Meyer (@Jordan-Meyer-19)
# Jessica Shu (@Jessicashu) requests $183.00 from Dixee Kimball (@Dixee-Kimball)
# Jessica Shu (@Jessicashu) requests $1576.00 from Amrit Ayalur (@amrit)
# Jonathan Wang (@jjxwang) requests $198.40 from Dixee Kimball (@Dixee-Kimball)
# Jonathan Wang (@jjxwang) requests $3111.60 from Roy Nakamaejo (@Roy-Nakamaejo)
# Kevin Feng (@Kevin-feng-5) requests $303.00 from Jonathan Zhou (@jonathanzhou)
# Kevin Feng (@Kevin-feng-5) requests $1039.00 from Bill Cao (@Bill-Cao)
# Victor Dong (@victor-dong) requests $1.00 from Jonathan Zhou (@jonathanzhou)
# Victor Dong (@victor-dong) requests $427.00 from Alex Pae (@Alexanderpae)
# Victor Garcia (@vmgarcia12) requests $31.00 from Kevin Huang (@Kevin_Huang)
# Victor Garcia (@vmgarcia12) requests $429.00 from Eric He (@eric_he)
# Victor Garcia (@vmgarcia12) requests $16.01 from Alex Dai (@Alex-dai)
# Victor Garcia (@vmgarcia12) requests $10.59 from Dixee Kimball (@Dixee-Kimball)
# Victor Garcia (@vmgarcia12) requests $25.62 from Dennis Wei (@DennisWei)
# Victor Garcia (@vmgarcia12) requests $2000.00 from Jarry Xiao (@Jarry-Xiao)
# Will Zhang (@will-zhang-2) requests $979.00 from Kunal Roy (@Kunal-Roy-1)
# Will Zhang (@will-zhang-2) requests $315.89 from Christopher Chu (@Chris-Chu-8)
# Yiwen Song (@yiwen-song) requests $10.53 from Jonathan Zhou (@jonathanzhou)
# Yiwen Song (@yiwen-song) requests $20.00 from Ben Low (@benlowkh)
